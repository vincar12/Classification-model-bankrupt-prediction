# %% [markdown]
# # Model Inferencing

# %% [markdown]
# Inferencing untuk model klasifikasi dataset usaha bangkrut

# %% [markdown]
# ### Import Library

# %%
# import libraries
import pandas as pd
import pickle

# %% [markdown]
# ### Load Model

# %%
# load model
with open('model.pkl', 'rb') as file_1:
    model_model = pickle.load(file_1)

# %% [markdown]
# ### Load inference data

# %%
# load inference data
data_in = pd.read_csv('/Users/vincartheoseta/Hacktiv/Phase 1/M2/p1-ftds018-hck-m2-vincar12/data_inf.csv')

# %% [markdown]
# ### Predict

# %% [markdown]
# Menggunakan model untuk memprediksi target data inferencing

# %%
# predict default
infer = model_model.predict(data_in)
infer
# Out:
# array([0, 0, 0])

# %% [markdown]
# Memasukkan hasil prediksi ke dalam dataframe inference

# %%
# input default into inference dataframe
data_in["Predict"] = infer
data_in
# Out:
#    ROA(C) before interest and depreciation before interest  \
# 0                                           0.481353
# 1                                           0.516209
# 2                                           0.556281
#
#    ROA(A) before interest and % after tax  \
# 0                                0.546664
# 1                                0.573485
# 2                                0.595345
#
#    ROA(B) before interest and depreciation after tax  Operating Gross Margin  \
# 0                                           0.532363                0.598373
# 1                                           0.558113                0.603619
# 2                                           0.607527                0.609529
#
#    Realized Sales Gross Margin  Operating Profit Rate  \
# 0                     0.598373               0.998977
# 1                     0.603619               0.999044
# 2                     0.609529               0.999061
#
# ...

# %% [markdown]
# Insight:
# - Model memprediksi semua data inferencing tidak mengalami kebangkrutan

# %% [markdown]
# Cek hasil prediksi dengan data asli

# %%
# show actual data targets
df0 = pd.read_csv('/Users/vincartheoseta/Hacktiv/Phase 1/M2/p1-ftds018-hck-m2-vincar12/data_inf_target.csv')
df0
# Out:
#    Bankrupt?  ROA(C) before interest and depreciation before interest  \
# 0          0                                           0.481353
# 1          0                                           0.516209
# 2          0                                           0.556281
#
#    ROA(A) before interest and % after tax  \
# 0                                0.546664
# 1                                0.573485
# 2                                0.595345
#
#    ROA(B) before interest and depreciation after tax  Operating Gross Margin  \
# 0                                           0.532363                0.598373
# 1                                           0.558113                0.603619
# 2                                           0.607527                0.609529
#
#    Realized Sales Gross Margin  Operating Profit Rate  \
# 0                     0.598373               0.998977
# 1                     0.603619               0.999044
# ...

# %% [markdown]
# Insight:
# - Prediksi model benar, semua data tidak bangkrut
